# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car=pd.read_csv(r"C:\Users\jalli\OneDrive\Desktop\car data.csv")
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
print(car['Selling_type'].unique())
print(car['Fuel_Type'].unique())
print(car['Transmission'].unique())
print(car['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car.duplicated().sum()
# Out:
# 2

# %%
car.drop_duplicates(inplace= True)

# %%
car.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
car['Year']=pd.to_datetime(car["Year"],format='%Y').dt.year

# %%
car['owner']=car["Owner"].astype("int32")
car["Driven_kms"]=car["Driven_kms"].astype("int32")

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Year           299 non-null    int32
#  2   Selling_Price  299 non-null    float64
#  3   Present_Price  299 non-null    float64
#  4   Driven_kms     299 non-null    int32
#  5   Fuel_Type      299 non-null    object
#  6   Selling_type   299 non-null    object
#  7   Transmission   299 non-null    object
#  8   Owner          299 non-null    int64
#  9   owner          299 non-null    int32
# dtypes: float64(2), int32(3), int64(1), object(4)
# memory usage: 22.2+ KB

# %%
car["Year"].unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007])

# %%
car["Year"].nunique()
# Out:
# 16

# %%
car=car.drop(columns="Car_Name")

# %%
car["current year"]=2023

# %%
car['Age of car']=car["current year"]-car["Year"]

# %%
car
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0    2014           3.35           5.59       27000    Petrol       Dealer
# 1    2013           4.75           9.54       43000    Diesel       Dealer
# 2    2017           7.25           9.85        6900    Petrol       Dealer
# 3    2011           2.85           4.15        5200    Petrol       Dealer
# 4    2014           4.60           6.87       42450    Diesel       Dealer
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Dealer
# 297  2015           4.00           5.90       60000    Petrol       Dealer
# 298  2009           3.35          11.00       87934    Petrol       Dealer
# 299  2017          11.50          12.50        9000    Diesel       Dealer
# 300  2016           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  owner  current year  Age of car
# 0         Manual      0      0          2023           9
# 1         Manual      0      0          2023          10
# 2         Manual      0      0          2023           6
# 3         Manual      0      0          2023          12
# 4         Manual      0      0          2023           9
# ..           ...    ...    ...           ...         ...
# 296       Manual      0      0          2023           7
# 297       Manual      0      0          2023           8
# 298       Manual      0      0          2023          14
# 299       Manual      0      0          2023           6
# 300       Manual      0      0          2023           7
#
# [299 rows x 11 columns]

# %%
car=car.drop(columns=["current year","Year"])
car
# Out:
#      Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0             3.35           5.59       27000    Petrol       Dealer
# 1             4.75           9.54       43000    Diesel       Dealer
# 2             7.25           9.85        6900    Petrol       Dealer
# 3             2.85           4.15        5200    Petrol       Dealer
# 4             4.60           6.87       42450    Diesel       Dealer
# ..             ...            ...         ...       ...          ...
# 296           9.50          11.60       33988    Diesel       Dealer
# 297           4.00           5.90       60000    Petrol       Dealer
# 298           3.35          11.00       87934    Petrol       Dealer
# 299          11.50          12.50        9000    Diesel       Dealer
# 300           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  owner  Age of car
# 0         Manual      0      0           9
# 1         Manual      0      0          10
# 2         Manual      0      0           6
# 3         Manual      0      0          12
# 4         Manual      0      0           9
# ..           ...    ...    ...         ...
# 296       Manual      0      0           7
# 297       Manual      0      0           8
# 298       Manual      0      0          14
# 299       Manual      0      0           6
# 300       Manual      0      0           7
#
# [299 rows x 9 columns]

# %%
car=pd.get_dummies(data=car,drop_first=True)

# %%
car
# Out:
#      Selling_Price  Present_Price  Driven_kms  Owner  owner  Age of car  \
# 0             3.35           5.59       27000      0      0           9
# 1             4.75           9.54       43000      0      0          10
# 2             7.25           9.85        6900      0      0           6
# 3             2.85           4.15        5200      0      0          12
# 4             4.60           6.87       42450      0      0           9
# ..             ...            ...         ...    ...    ...         ...
# 296           9.50          11.60       33988      0      0           7
# 297           4.00           5.90       60000      0      0           8
# 298           3.35          11.00       87934      0      0          14
# 299          11.50          12.50        9000      0      0           6
# 300           5.30           5.90        5464      0      0           7
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0               False              True                    False
# 1                True             False                    False
# 2               False              True                    False
# 3               False              True                    False
# 4                True             False                    False
# ..                ...               ...                      ...
# 296              True             False                    False
# 297             False              True                    False
# 298             False              True                    False
# 299              True             False                    False
# 300             False              True                    False
#
#      Transmission_Manual
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 296                 True
# 297                 True
# 298                 True
# 299                 True
# 300                 True
#
# [299 rows x 10 columns]

# %%
g=['Fuel_Type_Diesel','Fuel_Type_Petrol','Selling_type_Individual','Transmission_Manual']
car[g]=car[g].astype('int')

# %%
car.head(3)
# Out:
#    Selling_Price  Present_Price  Driven_kms  Owner  owner  Age of car  \
# 0           3.35           5.59       27000      0      0           9
# 1           4.75           9.54       43000      0      0          10
# 2           7.25           9.85        6900      0      0           6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0                 0                 1                        0
# 1                 1                 0                        0
# 2                 0                 1                        0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1

# %%
car.corr()
# Out:
#                          Selling_Price  Present_Price  Driven_kms     Owner  \
# Selling_Price                 1.000000       0.876305    0.028566 -0.087880
# Present_Price                 0.876305       1.000000    0.205224  0.009948
# Driven_kms                    0.028566       0.205224    1.000000  0.089367
# Owner                        -0.087880       0.009948    0.089367  1.000000
# owner                        -0.087880       0.009948    0.089367  1.000000
# Age of car                   -0.234369       0.053167    0.525714  0.181639
# Fuel_Type_Diesel              0.543541       0.464934    0.173295 -0.051836
# Fuel_Type_Petrol             -0.531636      -0.456829   -0.173595  0.054102
# Selling_type_Individual      -0.553851      -0.511779   -0.101030  0.123646
# Transmission_Manual          -0.348869      -0.334326   -0.163881 -0.052166
#
#                             owner  Age of car  Fuel_Type_Diesel  \
# Selling_Price           -0.087880   -0.234369          0.543541
# Present_Price            0.009948    0.053167          0.464934
# Driven_kms               0.089367    0.525714          0.173295
# Owner                    1.000000    0.181639         -0.051836
# owner                    1.000000    0.181639         -0.051836
# Age of car               0.181639    1.000000         -0.056469
# Fuel_Type_Diesel        -0.051836   -0.056469          1.000000
# Fuel_Type_Petrol         0.054102    0.052197         -0.979104
# Selling_type_Individual  0.123646    0.036820         -0.345882
# Transmission_Manual     -0.052166   -0.003434         -0.086264
#
#                          Fuel_Type_Petrol  Selling_type_Individual  \
# Selling_Price                   -0.531636                -0.553851
# Present_Price                   -0.456829                -0.511779
# Driven_kms                      -0.173595                -0.101030
# Owner                            0.054102                 0.123646
# owner                            0.054102                 0.123646
# Age of car                       0.052197                 0.036820
# Fuel_Type_Diesel                -0.979104                -0.345882
# Fuel_Type_Petrol                 1.000000                 0.353865
# Selling_type_Individual          0.353865                 1.000000
# Transmission_Manual              0.078700                 0.058669
#
#                          Transmission_Manual
# Selling_Price                      -0.348869
# Present_Price                      -0.334326
# Driven_kms                         -0.163881
# Owner                              -0.052166
# owner                              -0.052166
# Age of car                         -0.003434
# Fuel_Type_Diesel                   -0.086264
# Fuel_Type_Petrol                    0.078700
# Selling_type_Individual             0.058669
# Transmission_Manual                 1.000000

# %%
import warnings


warnings.filterwarnings("ignore")
sns.pairplot(car)

# %%
y=car['Selling_Price']
x=car.drop(columns=['Selling_Price'])

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
x
# Out:
#      Present_Price  Driven_kms  Owner  owner  Age of car  Fuel_Type_Diesel  \
# 0             5.59       27000      0      0           9                 0
# 1             9.54       43000      0      0          10                 1
# 2             9.85        6900      0      0           6                 0
# 3             4.15        5200      0      0          12                 0
# 4             6.87       42450      0      0           9                 1
# ..             ...         ...    ...    ...         ...               ...
# 296          11.60       33988      0      0           7                 1
# 297           5.90       60000      0      0           8                 0
# 298          11.00       87934      0      0          14                 0
# 299          12.50        9000      0      0           6                 1
# 300           5.90        5464      0      0           7                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                   1                        0                    1
# 1                   0                        0                    1
# 2                   1                        0                    1
# 3                   1                        0                    1
# 4                   0                        0                    1
# ..                ...                      ...                  ...
# 296                 0                        0                    1
# 297                 1                        0                    1
# 298                 1                        0                    1
# 299                 0                        0                    1
# 300                 1                        0                    1
#
# [299 rows x 9 columns]

# %%
import warnings
warnings.filterwarnings("ignore")
sns.pairplot(car)

# %%
feat_importances=pd.Series(model.feature_importances_,index=x.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[292], line 1
# ----> 1 feat_importances=pd.Series(model.feature_importances_,index=x.columns)
#       2 feat_importances.nlargest(5).plot(kind='barh')
#       3 plt.show()
#
# NameError: name 'model' is not defined

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train.shape

# %%
x_test.shape

# %%
feat_importances=pd.Series(model.feature_importances_,index=x.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
ypred=regressor.predict(x_test)

# %%
ypred

# %%
from sklearn.metrics import r2_score
r2_score(y_test,ypred)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters={
    'n_estimators':[100,200,300,400,500,600,700,800,900,1000],
    'criterion':['squared_error','absolute_error','poisson','friedman_mse'],
    'max_depth':[10,20,30,40,50],
    'min_samples_split':[2,5,10,20,50],
    'min_samples_leaf':[1,2,5,10],
    'max_features':['auto','sqrt','log2']
}

# %%
parameters

# %%
random_cv=RandomizedSearchCV(estimator=regressor,param_distributions=parameters,n_iter=10,
                             scoring='neg_mean_absolute_error',random_state=42,cv=5,verbose=2,n_jobs=-1)

# %%
random_cv.fit(x_train,y_train)

# %%
random_cv.best_params_

# %%
random_cv.best_score_

# %%
predictions=random_cv.predict(x_test)

# %%
sns.distplot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE:',metrics.mean_absolute_error(y_test,predictions))
print('MSE:',metrics.mean_squared_error(y_test,predictions))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,predictions)))

# %%
x.head(3)

# %%
single_ob=np.array([9.5,15000,0.0,5.0,1.0,0.0,0.0,1.0])
single_ob=single_ob.reshape(1,-1)
